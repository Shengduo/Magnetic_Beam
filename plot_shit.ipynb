# %%
# Import packages
import plotly
from plotly import graph_objects as go
import polars as pl
import numpy as np

# %%
pl.__version__
# Out:
# '1.8.2'

# %%
# raw_dump = pd.read_excel('/Users/shengduoliu/Documents/Yoonho/src/rawDump.xlsx', sheet_name=1)
raw_dump = pl.read_csv('./rawDump_1.csv', 
                       try_parse_dates=True, 
                       encoding='ISO-8859-1')
raw_dump = raw_dump.with_columns(
    pl.col('Set up date').cast(pl.Utf8)
    .str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Pick up date').cast(pl.Utf8).str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Start time').str.strptime(pl.Time, "%H:%M"), 
    pl.col('End time').str.strptime(pl.Time, "%H:%M")
)
raw_dump
# Out:
# shape: (30, 158)
# ┌─────┬─────────┬─────────────────┬─────────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ No  ┆ Home ID ┆ Household       ┆ Address         ┆ … ┆ Pb (µg/g) ┆ Th (µg/g) ┆ U (µg/g)  ┆      │
# │ --- ┆ ---     ┆ ---             ┆ ---             ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---  │
# │ i64 ┆ i64     ┆ str             ┆ str             ┆   ┆ f64       ┆ f64       ┆ f64       ┆ str  │
# ╞═════╪═════════╪═════════════════╪═════════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ 1   ┆ 1       ┆ Feng Gao        ┆ 11070           ┆ … ┆ 1.993528  ┆ -0.000604 ┆ 0.000777  ┆ null │
# │     ┆         ┆                 ┆ Strathmore Dr,  ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Angel…      ┆   ┆           ┆           ┆           ┆      │
# │ 2   ┆ 1       ┆ Feng Gao        ┆ 11070           ┆ … ┆ 2.473373  ┆ -0.002462 ┆ 0.00073   ┆ null │
# │     ┆         ┆                 ┆ Strathmore Dr,  ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Angel…      ┆   ┆           ┆           ┆           ┆      │
# │ 3   ┆ 2       ┆ Jing Li         ┆ 3430 S          ┆ … ┆ 0.941772  ┆ 0.0012827 ┆ 0.001269  ┆ null │
# │     ┆         ┆                 ┆ Sepulveda Blvd, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Ang…        ┆   ┆           ┆           ┆           ┆      │
# │ 4   ┆ 2       ┆ Jing Li         ┆ 3430 S          ┆ … ┆ 0.765385  ┆ -0.008923 ┆ 0.000431  ┆ null │
# │     ┆         ┆                 ┆ Sepulveda Blvd, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Ang…        ┆   ┆           ┆           ┆           ┆      │
# │ 5   ┆ 3       ┆ Muchuan Niu     ┆ 145 W Del Mar   ┆ … ┆ 3.166795  ┆ 0.00136   ┆ 0.000869  ┆ null │
# │     ┆         ┆                 ┆ Blvd, Pasadena, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ …               ┆   ┆           ┆           ┆           ┆      │
# │ …   ┆ …       ┆ …               ┆ …               ┆ … ┆ …         ┆ …         ┆ …         ┆ …    │
# │ 32  ┆ 14      ┆ Beate Ritz      ┆ 20170           ┆ … ┆ 0.021308  ┆ -0.006056 ┆ 0.00008   ┆ null │
# │     ┆         ┆                 ┆ Observation Dr, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Topanga,…       ┆   ┆           ┆           ┆           ┆      │
# │ 33  ┆ 14      ┆ Beate Ritz      ┆ 20170           ┆ … ┆ 0.116375  ┆ -0.000865 ┆ 0.0010525 ┆ null │
# │     ┆         ┆                 ┆ Observation Dr, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Topanga,…       ┆   ┆           ┆           ┆           ┆      │
# │ 10  ┆ 6       ┆ Yifang Zhu      ┆ 10418 Windtree  ┆ … ┆ 0.077845  ┆ -0.000182 ┆ 0.000222  ┆ null │
# │     ┆         ┆                 ┆ Dr, Los         ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Angeles…        ┆   ┆           ┆           ┆           ┆      │
# │ 7   ┆ 4       ┆ Michael Jerrett ┆ 234 Dimmick     ┆ … ┆ 0.093496  ┆ -0.000013 ┆ 0.000184  ┆ null │
# │     ┆         ┆                 ┆ Ave, Venice, CA ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ 90…             ┆   ┆           ┆           ┆           ┆      │
# │ 25  ┆ 10      ┆ Jiachen Zhang   ┆ 911 Flanders    ┆ … ┆ 0.106767  ┆ 0.000277  ┆ 0.000345  ┆ null │
# │     ┆         ┆                 ┆ Rd, La Canada   ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Fli…            ┆   ┆           ┆           ┆           ┆      │
# └─────┴─────────┴─────────────────┴─────────────────┴───┴───────────┴───────────┴───────────┴──────┘

# %%
raw_dump.columns
# Out:
# ['No',
#  'Home ID',
#  'Household',
#  'Address',
#  'Round',
#  'Set up date',
#  'Pick up date',
#  'Indoor or outdoor',
#  'UPAS ID',
#  'Filter ID',
#  'Flow rate',
#  'Sample volume (L)',
#  'Sample volume (m3)',
#  'Filter ID_duplicated_0',
#  'PM2.5 mass (mg)',
#  'PM2.5 (µg/m3)',
#  'BC (µg/m3)',
#  'Home ID_duplicated_0',
#  'Indoor or outdoor_duplicated_0',
#  'BTEX ID',
#  'Start time',
#  'End time',
#  '1,3-Butadiene (ppb)',
#  '3-Chloropropene (ppb)',
#  'Ethene, 1,1-dichloro-  (ppb)',
#  'Ethane, 1,1-dichloro-  (ppb)',
#  'n-Hexane  (ppb)',
#  'Chloroform  (ppb)',
#  '1,2-Dichloroethane  (ppb)',
#  'Ethane, 1,1,1-trichloro-  (ppb)',
#  'Carbon Tetrachloride  (ppb)',
#  'Benzene  (ppb)',
#  'Heptane  (ppb)',
#  'Propane, 1,2-dichloro-  (ppb)',
#  'Trichloroethene  (ppb)',
#  'Ethane, 1,1,2-trichloro-  (ppb)',
#  'Toluene  (ppb)',
#  'Tetrachloroethene  (ppb)',
#  'Benzene, chloro-  (ppb)',
#  'Ethylbenzene  (ppb)',
#  'm,p-Xylene  (ppb)',
#  'Styrene  (ppb)',
#  'o-Xylene  (ppb)',
#  '1,4-Dichlorobenzene  (ppb)',
#  'BTEX (ppb)',
#  'Filter ID_duplicated_1',
#  'Filter ID_duplicated_2',
#  'Li (ng/m3)',
#  'Be (ng/m3)',
#  'B (ng/m3)',
#  'Na (ng/m3)',
#  'Mg (ng/m3)',
#  'Al (ng/m3)',
#  'P (ng/m3)',
#  'S (ng/m3)',
#  'K (ng/m3)',
#  'Ca (ng/m3)',
#  'Sc (ng/m3)',
#  'Ti (ng/m3)',
#  'V (ng/m3)',
#  'Cr (ng/m3)',
#  'Mn (ng/m3)',
#  'Fe (ng/m3)',
#  'Co (ng/m3)',
#  'Ni (ng/m3)',
#  'Cu (ng/m3)',
#  'Zn (ng/m3)',
#  'As (ng/m3)',
#  'Se (ng/m3)',
#  'Rb (ng/m3)',
#  'Sr (ng/m3)',
#  'Y (ng/m3)',
#  'Nb (ng/m3)',
#  'Mo (ng/m3)',
#  'Ru (ng/m3)',
#  'Rh (ng/m3)',
#  'Pd (ng/m3)',
#  'Ag (ng/m3)',
#  'Cd (ng/m3)',
#  'Sn (ng/m3)',
#  'Sb (ng/m3)',
#  'Cs (ng/m3)',
#  'Ba (ng/m3)',
#  'La (ng/m3)',
#  'Ce (ng/m3)',
#  'Pr (ng/m3)',
#  'Nd (ng/m3)',
#  'Sm (ng/m3)',
#  'Eu (ng/m3)',
#  'Dy (ng/m3)',
#  'Ho (ng/m3)',
#  'Yb (ng/m3)',
#  'Lu (ng/m3)',
#  'Hf (ng/m3)',
#  'Ta (ng/m3)',
#  'W (ng/m3)',
#  'Pt (ng/m3)',
#  'Hg (ng/m3)',
#  'Tl (ng/m3)',
#  'Pb (ng/m3)',
#  'Th (ng/m3)',
#  'U (ng/m3)',
#  'Li (µg/g)',
#  'Be (µg/g)',
#  'B (µg/g)',
#  'Na (µg/g)',
#  'Mg (µg/g)',
#  'Al (µg/g)',
#  'P (µg/g)',
#  'S (µg/g)',
#  'K (µg/g)',
#  'Ca (µg/g)',
#  'Sc (µg/g)',
#  'Ti (µg/g)',
#  'V (µg/g)',
#  'Cr (µg/g)',
#  'Mn (µg/g)',
#  'Fe (µg/g)',
#  'Co (µg/g)',
#  'Ni (µg/g)',
#  'Cu (µg/g)',
#  'Zn (µg/g)',
#  'As (µg/g)',
#  'Se (µg/g)',
#  'Rb (µg/g)',
#  'Sr (µg/g)',
#  'Y (µg/g)',
#  'Nb (µg/g)',
#  'Mo (µg/g)',
#  'Ru (µg/g)',
#  'Rh (µg/g)',
#  'Pd (µg/g)',
#  'Ag (µg/g)',
#  'Cd (µg/g)',
#  'Sn µg/g)',
#  'Sb (µg/g)',
#  'Cs (µg/g)',
#  'Ba (µg/g)',
#  'La (µg/g)',
#  'Ce (µg/g)',
#  'Pr (µg/g)',
#  'Nd (µg/g)',
#  'Sm (µg/g)',
#  'Eu (µg/g)',
#  'Dy (µg/g)',
#  'Ho (µg/g)',
#  'Yb (µg/g)',
#  'Lu (µg/g)',
#  'Hf (µg/g)',
#  'Ta (µg/g)',
#  'W (µg/g)',
#  'Pt (µg/g)',
#  'Hg (µg/g)',
#  'Tl (µg/g)',
#  'Pb (µg/g)',
#  'Th (µg/g)',
#  'U (µg/g)']

# %%
df
# Out:
#     No  Home ID          Household  \
# 0    1        1           Feng Gao
# 1    2        1           Feng Gao
# 2    3        2            Jing Li
# 3    4        2            Jing Li
# 4    5        3        Muchuan Niu
# 5    6        3        Muchuan Niu
# 6    7        4    Michael Jerrett
# 7    8        4    Michael Jerrett
# 8    9        5  Jonathan Fielding
# 9   10        6         Yifang Zhu
# 10  12        6     Yifang Zhu (J)
# 11  14        7               UCLA
# 12  15        7               UCLA
# 13  16        8           Yuan Yao
# 14  17        8           Yuan Yao
# 15  22        9           Jiaqi Ma
# 16  23        9           Jiaqi Ma
# 17  24       10      Jiachen Zhang
# 18  25       10      Jiachen Zhang
# 14  (Sawtelle Creek, 90066, Los Angeles, Californi...  34.015773 -118.427704
# 15  (Baptiste Way, 91011, La Cañada Flintridge, Ca...  34.200483 -118.183353
# 16  (Baptiste Way, 91011, La Cañada Flintridge, Ca...  34.200483 -118.183353
# 17  (La Cañada Flintridge, 91011, California, Unit...  34.199830 -118.200524
# 18  (La Cañada Flintridge, 91011, California, Unit...  34.199830 -118.200524
# 19  (1572, Casa Grande Street, 91104, Casa Grande ...  34.162924 -118.118025
# 23  (Santa Monica College, 18th Street, 90404, 18t...  34.016711 -118.470761
# 25  (Topanga Skyline Drive, 90290, California, Uni...  34.111122 -118.625146
#
# [22 rows x 160 columns]

# %%
# Raw_data
raw_dump = pl.read_csv('./rawDump_1.csv', 
                         # shit_id=1, 
                         try_parse_dates=True, 
                         encoding='ISO-8859-1')
df = raw_dump.with_columns(
    pl.col('Set up date').cast(pl.Utf8)
    .str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Pick up date').cast(pl.Utf8).str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Start time').str.strptime(pl.Time, "%H:%M"), 
    pl.col('End time').str.strptime(pl.Time, "%H:%M")
).to_pandas().dropna()
# Out:
# shape: (30, 158)
# ┌─────┬─────────┬─────────────────┬─────────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ No  ┆ Home ID ┆ Household       ┆ Address         ┆ … ┆ Pb (µg/g) ┆ Th (µg/g) ┆ U (µg/g)  ┆      │
# │ --- ┆ ---     ┆ ---             ┆ ---             ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---  │
# │ i64 ┆ i64     ┆ str             ┆ str             ┆   ┆ f64       ┆ f64       ┆ f64       ┆ str  │
# ╞═════╪═════════╪═════════════════╪═════════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ 1   ┆ 1       ┆ Feng Gao        ┆ 11070           ┆ … ┆ 1.993528  ┆ -0.000604 ┆ 0.000777  ┆ null │
# │     ┆         ┆                 ┆ Strathmore Dr,  ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Angel…      ┆   ┆           ┆           ┆           ┆      │
# │ 2   ┆ 1       ┆ Feng Gao        ┆ 11070           ┆ … ┆ 2.473373  ┆ -0.002462 ┆ 0.00073   ┆ null │
# │     ┆         ┆                 ┆ Strathmore Dr,  ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Angel…      ┆   ┆           ┆           ┆           ┆      │
# │ 3   ┆ 2       ┆ Jing Li         ┆ 3430 S          ┆ … ┆ 0.941772  ┆ 0.0012827 ┆ 0.001269  ┆ null │
# │     ┆         ┆                 ┆ Sepulveda Blvd, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Ang…        ┆   ┆           ┆           ┆           ┆      │
# │ 4   ┆ 2       ┆ Jing Li         ┆ 3430 S          ┆ … ┆ 0.765385  ┆ -0.008923 ┆ 0.000431  ┆ null │
# │     ┆         ┆                 ┆ Sepulveda Blvd, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Los Ang…        ┆   ┆           ┆           ┆           ┆      │
# │ 5   ┆ 3       ┆ Muchuan Niu     ┆ 145 W Del Mar   ┆ … ┆ 3.166795  ┆ 0.00136   ┆ 0.000869  ┆ null │
# │     ┆         ┆                 ┆ Blvd, Pasadena, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ …               ┆   ┆           ┆           ┆           ┆      │
# │ …   ┆ …       ┆ …               ┆ …               ┆ … ┆ …         ┆ …         ┆ …         ┆ …    │
# │ 32  ┆ 14      ┆ Beate Ritz      ┆ 20170           ┆ … ┆ 0.021308  ┆ -0.006056 ┆ 0.00008   ┆ null │
# │     ┆         ┆                 ┆ Observation Dr, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Topanga,…       ┆   ┆           ┆           ┆           ┆      │
# │ 33  ┆ 14      ┆ Beate Ritz      ┆ 20170           ┆ … ┆ 0.116375  ┆ -0.000865 ┆ 0.0010525 ┆ null │
# │     ┆         ┆                 ┆ Observation Dr, ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Topanga,…       ┆   ┆           ┆           ┆           ┆      │
# │ 10  ┆ 6       ┆ Yifang Zhu      ┆ 10418 Windtree  ┆ … ┆ 0.077845  ┆ -0.000182 ┆ 0.000222  ┆ null │
# │     ┆         ┆                 ┆ Dr, Los         ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Angeles…        ┆   ┆           ┆           ┆           ┆      │
# │ 7   ┆ 4       ┆ Michael Jerrett ┆ 234 Dimmick     ┆ … ┆ 0.093496  ┆ -0.000013 ┆ 0.000184  ┆ null │
# │     ┆         ┆                 ┆ Ave, Venice, CA ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ 90…             ┆   ┆           ┆           ┆           ┆      │
# │ 25  ┆ 10      ┆ Jiachen Zhang   ┆ 911 Flanders    ┆ … ┆ 0.106767  ┆ 0.000277  ┆ 0.000345  ┆ null │
# │     ┆         ┆                 ┆ Rd, La Canada   ┆   ┆           ┆           ┆           ┆      │
# │     ┆         ┆                 ┆ Fli…            ┆   ┆           ┆           ┆           ┆      │
# └─────┴─────────┴─────────────────┴─────────────────┴───┴───────────┴───────────┴───────────┴──────┘

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly
from plotly import graph_objects as go
import plotly.express as px
import pandas as pd
import polars as pl
import numpy as np

# from geopy.geocoders import Photon
from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="my_user_agent")
geolocator = Nominatim(user_agent="Geopy Library")

# Raw_data: save sheet one in the same dir as rawDump_1.csv
raw_dump = pl.read_csv('./rawDump_1.csv',
                         try_parse_dates=True, 
                         encoding='ISO-8859-1')
df = raw_dump.with_columns(
    pl.col('Set up date').cast(pl.Utf8)
    .str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Pick up date').cast(pl.Utf8).str.zfill(8).str.strptime(pl.Date, "%m%d%Y"), 
    pl.col('Start time').str.strptime(pl.Time, "%H:%M"), 
    pl.col('End time').str.strptime(pl.Time, "%H:%M")
).to_pandas()

# Geocode addresses to latitude and longitude
# geolocator = Photon(user_agent="geoapiExercises")
df['location'] = df['Address'].apply(lambda x: geolocator.geocode(x, timeout=None))
df['latitude'] = df['location'].apply(lambda loc: loc.latitude if loc else None)
df['longitude'] = df['location'].apply(lambda loc: loc.longitude if loc else None)

# Columns to be selected from:
shits = [
 'PM2.5 mass (mg)',
 'PM2.5 (µg/m3)',
 'BC (µg/m3)',
 'Ho (µg/g)',
 'Yb (µg/g)',
 'Lu (µg/g)',
 'Ethane, 1,1-dichloro-  (ppb)',
 'n-Hexane  (ppb)',
 'Chloroform  (ppb)',
]

df[shits] = df[shits].fillna(0.)

# Round colors
plotly_colors = ['#636EFA', '#EF553B', '#00CC96', '#AB63FA', '#FFA15A', '#19D3F3', '#FF6692', '#B6E880', '#FF97FF', '#FECB52']
rd_colors = {idx : plotly_colors[idx] for idx in range(3)}

# Set up dash
app = dash.Dash(__name__)

app.layout = html.Div([
    html.Label("Select round:"),
    dcc.Checklist(
        id='Round',
        options=df['Round'].unique(),
        value=df['Round'].unique(), # Default value
        # multi=True, 
        inline=True, 
        # disable=True, 
    ),
    html.Label("In Or Out:"), 
    dcc.RadioItems(
        id='InOrOut', 
        options=df['Indoor or outdoor'].unique(), 
        value=df['Indoor or outdoor'].unique()[0], 
    ), 
    html.Label("Select shit:"), 
    dcc.Dropdown(
        id='Shits',
        options=shits,
        value=shits[0], # Default value
        multi=False
    ),
    dcc.Graph(id='my-plot')
])

@app.callback(
    Output('my-plot', 'figure'),
    Input('Round', 'value'), 
    Input('InOrOut', 'value'), 
    Input('Shits', 'value'), 
)
def update_plot(round, inOrOut, shit):
    this_df = df.loc[(df['Round'].isin(round)) & 
                     (df['Indoor or outdoor'] == inOrOut)]
    # Find correct barheight
    median_bar_height = 25
    max_bar_height = 30
    min_bar_height = 20
    this_df[shit] = this_df[shit].clip(lower=0., )
    if this_df[shit].median() == 0.:
        normalizer = this_df[shit].mean()
        if normalizer == 0.:
            this_df[f'plot_{shit}_ht'] = min_bar_height
        else:
            this_df[f'plot_{shit}_ht'] = this_df[shit] / normalizer * median_bar_height
    else:
        normalizer = this_df[shit].median() 
        this_df[f'plot_{shit}_ht'] = this_df[shit] / normalizer * median_bar_height
    
    this_df[f'plot_{shit}_ht'] = this_df[f'plot_{shit}_ht'].clip(lower=min_bar_height, 
                                                                 upper=max_bar_height)
    this_df[f'text_{shit}'] = this_df.apply(lambda row: f"Home ID = {row['Home ID']} \n {shit} = {row[shit]}", axis=1)

    fig = go.Figure()

    for rd in round:
        plot_df = this_df.loc[this_df['Round'] == rd]

        fig.add_traces(go.Scattermap(
            lat=plot_df['latitude'],
            lon=plot_df['longitude'],
            mode='markers',
            marker=go.scattermap.Marker(
                # symbol='square', 
                size=plot_df[f'plot_{shit}_ht'], 
                color=rd_colors[rd], 
                # autocolorscale=True, 
                # colorbar=dict(
                #     title=dict(
                #         text=shit, 
                #     )
                # )
            ),
            customdata=np.stack([plot_df['Home ID'], plot_df[shit]], axis=-1), 
            hovertemplate = "<b> Home ID : %{customdata[0]} <br>" + 
            f"<b>{shit}" + " : %{customdata[1]}", 
            name=f'Round {rd}', 
        ))

    fig.update_layout(
        hovermode='closest',
        autosize=True, 
        width=1200,  # Set the width to 800 pixels
        height=900, # Set the height to 600 pixels
        map=dict(
            bearing=0,
            center=go.layout.map.Center(
                lat=df['latitude'].mean(),
                lon=df['longitude'].mean(), 
            ),
            pitch=0,
            zoom=10, 
        ), 
        showlegend=True, 
        legend=dict(
            orientation='h', 
            xanchor='auto', 
            yanchor='bottom', 
            itemsizing='constant', # Ensures all legend markers have the same size
            traceorder='normal',
            font=dict(
                family='sans-serif',
                size=20,
                color='black'
            ),
        ),
    )
    return fig


app.run_server(debug=True, 
               port='8100', 
               jupyter_mode='external', )
# Out:
# Dash app running on http://127.0.0.1:8100/
# <ipython-input-10-aa88f1b0f848>:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:105: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:107: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:109: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.loc[(df['Round'] == 2) & (df['Indoor or outdoor'] == 'Outdoor')]
# Out:
#     No  Home ID       Household  \
# 16  23        9        Jiaqi Ma
# 18  25       10   Jiachen Zhang
# 20  27       11          Aakila
# 22  29       12   Leah Kessler
# 24  31       13  Miriam Marlier
# 26  33       14      Beate Ritz
#
#                                               Address  Round Set up date  \
# 16  347 Baptiste Way, La Canada Flintridge, CA 91011       2  2025-01-23
# 18    911 Flanders Rd, La Canada Flintridge, CA 91011      2  2025-01-23
# 20            1572 Casa Grande St, Pasadena, CA 91104      2  2025-01-23
# 22     13878 Sunset Blvd, Pacific Palisades, CA 90272      2  2025-01-24
# 24                221 25th St, Santa Monica, CA 90402      2  2025-01-24
# 26            20170 Observation Dr, Topanga, CA 90290      2  2025-01-24
#
#    Pick up date Indoor or outdoor  UPAS ID  Filter ID  ...  Pt (µg/g)  \
# 16   2025-01-31           Outdoor    352.0  2430229.0  ...  -0.000069
# 18   2025-01-31           Outdoor    382.0  2430231.0  ...  -0.000035
# 20   2025-01-31           Outdoor    385.0    92416.0  ...        NaN
# 22   2025-01-31           Outdoor    343.0  2430234.0  ...  -0.000088
# 24   2025-01-31           Outdoor    345.0  2430235.0  ...   0.000003
# 26   2025-01-31           Outdoor    386.0  2430237.0  ...   0.000056
#
#     Hg (µg/g)  Tl (µg/g) Pb (µg/g)  Th (µg/g)  U (µg/g)        \
# 16  -0.007014   0.000013  0.021370  -0.003329  0.000098  None
# 18  -0.011129   0.000086  0.075248  -0.005347  0.000299  None
# 20        NaN        NaN       NaN        NaN       NaN  None
# 22  -0.013459   0.000022  0.052706  -0.007271  0.000099  None
# 24  -0.009902   0.000125  0.080492  -0.004656  0.000513  None
# 26  -0.007125   0.000271  0.116375  -0.000865  0.001053  None
#
#                                              location   latitude   longitude
# 16  (347, Baptiste Way, La Cañada Flintridge, Los ...  34.200580 -118.185254
# 18  (911, Flanders Road, La Cañada Flintridge, Los...  34.210587 -118.200005
# 20  (1572, Casa Grande Street, Bungalow Heaven, Pa...  34.162924 -118.118025
# 22  (West Sunset Boulevard, Pacific Palisades, Los...  34.049597 -118.528975
# 24  (221, 25th Street, Santa Monica, Los Angeles C...  34.047658 -118.492550
# 26                                               None        NaN         NaN
#
# [6 rows x 161 columns]
# <ipython-input-10-aa88f1b0f848>:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:105: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:107: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:109: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:96: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:105: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:107: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-10-aa88f1b0f848>:109: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# from geopy.geocoders import Photon
from geopy.geocoders import Photon, Nominatim
geolocator = Nominatim(user_agent="my_user_agent")
# geolocator = Photon(user_agent="Geopy Library")

loc = geolocator.geocode("19989 Sischo Dr, Topanga, CA 90290")
print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-04472d4b8826> in <module>
#       5
#       6 loc = geolocator.geocode("19989 Sischo Dr, Topanga, CA 90290")
# ----> 7 print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'
